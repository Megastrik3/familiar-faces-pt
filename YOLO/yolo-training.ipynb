# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.21-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata (22 kB)
# ...
#   Using cached polars-1.38.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.0-cp314-cp314-win_amd64.whl.metadata (119 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu130
# ...
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/1.9 GB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 GB 58.0 MB/s eta 0:00:33
#     --------------------------------------- 0.0/1.9 GB 73.4 MB/s eta 0:00:26
#     --------------------------------------- 0.0/1.9 GB 69.1 MB/s eta 0:00:27
#    - -------------------------------------- 0.1/1.9 GB 73.5 MB/s eta 0:00:25
#    - -------------------------------------- 0.1/1.9 GB 74.4 MB/s eta 0:00:25
#    -- ------------------------------------- 0.1/1.9 GB 76.0 MB/s eta 0:00:24
#    -- ------------------------------------- 0.1/1.9 GB 76.6 MB/s eta 0:00:24
# ...

# %%
from ultralytics import YOLO

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print("PyTorch is using the GPU.")
else:
    print("No GPU available. PyTorch will run on CPU.")
# Out:
# GPU: NVIDIA GeForce RTX 3070 Ti Laptop GPU is available.
# Number of GPUs available: 1
# PyTorch is using the GPU.

# %%
model = YOLO('C:\\Users\\megas\\Documents\\familiar-faces-pt\\YOLO\\yolo26n.pt')

results = model.train(data='./dataset/data.yaml', task='detect', epochs=100, imgsz=640, batch=16, name='yolo-familiar-faces', device=0)

model.export(format="onnx", dynamic=False)
# Out:
# Ultralytics 8.4.21  Python-3.14.3 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# ...

# %%
model.export(format="tflite")
# Out:
# Ultralytics 8.4.21  Python-3.14.3 torch-2.10.0+cu130 CPU (12th Gen Intel Core i9-12900H)
# YOLO26n summary (fused): 122 layers, 2,375,031 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from 'C:\Users\megas\Documents\proguard\kettering_proguard_ai\runs\detect\yolo-familiar-faces7\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.1 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0,<=2.19.0'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "tensorflow>=2.0.0,<=2.19.0" ' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "tensorflow>=2.0.0,<=2.19.0" ' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "tensorflow>=2.0.0,<=2.19.0" ' returned non-zero exit status 1.
# ERROR: Could not find a version that satisfies the requirement tensorflow<=2.19.0,>=2.0.0 (from versions: none)
# ...
